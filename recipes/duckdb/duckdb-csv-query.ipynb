# %% [markdown]
# # show and tell: duckdb csv query
# This is a quick recipe on using duckdb to query multiple csv files as a single dataset
# [more duckdb info](https://duckdb.org/docs/)

# %%
import duckdb
from bs4 import BeautifulSoup
import requests
import os

# %% [markdown]
# ## Setup duckdb database and load required extensions

# %%
conn = duckdb.connect(database=':memory:')

# %%
conn.install_extension("httpfs")
conn.load_extension("httpfs")
# conn.execute("INSTALL spatial;")
# conn.execute("LOAD spatial;")

# %% [markdown]
# ## Get some meaningful files for demo

# %%
url = 'https://www.for.gov.bc.ca/ftp/HPR/external/!publish/BCWS_DATA_MART/2023/'
r = requests.get('https://www.for.gov.bc.ca/ftp/HPR/external/!publish/BCWS_DATA_MART/2023/')
s = BeautifulSoup(r.content, "html.parser")
csv_list = [url+os.path.basename(a['href']) for a in s.find_all('a', href=True) if '.csv' in a['href']]

# %% [markdown]
# ## Filter 2023 files for November
# if csv files are local duckdb can use glob syntax to filter files eg 'tmp\2023\2023-11-*.csv'
# instead of a list. if you have parquet files this works over https. This was not the case for
# csv (2023-11-28)

# %%
nov_data = [csv for csv in csv_list if '2023-11-' in csv]

# %% [markdown]
# ## Read the data
# for performance with csv it better just to create a table in your duckdb database straight away but one can query a list of csv directly by using  read_csv_auto({nov_data}) in place of 'weather' in the SQL
# eg..
# ``` conn.sql(f'SELECT * FROM read_csv_auto({nov_data})') ```

# %%
conn.sql('DROP TABLE IF EXISTS weather')
conn.sql(f'CREATE TABLE weather AS SELECT * FROM read_csv_auto({nov_data})')

# %%
conn.sql(f"DESCRIBE weather")
# Out:
# ┌────────────────────────────────┬─────────────┬─────────┬─────────┬─────────┬───────┐
# │          column_name           │ column_type │  null   │   key   │ default │ extra │
# │            varchar             │   varchar   │ varchar │ varchar │ varchar │ int32 │
# ├────────────────────────────────┼─────────────┼─────────┼─────────┼─────────┼───────┤
# │ STATION_CODE                   │ BIGINT      │ YES     │ NULL    │ NULL    │  NULL │
# │ STATION_NAME                   │ VARCHAR     │ YES     │ NULL    │ NULL    │  NULL │
# │ DATE_TIME                      │ BIGINT      │ YES     │ NULL    │ NULL    │  NULL │
# │ HOURLY_PRECIPITATION           │ DOUBLE      │ YES     │ NULL    │ NULL    │  NULL │
# │ HOURLY_TEMPERATURE             │ DOUBLE      │ YES     │ NULL    │ NULL    │  NULL │
# │ HOURLY_RELATIVE_HUMIDITY       │ BIGINT      │ YES     │ NULL    │ NULL    │  NULL │
# │ HOURLY_WIND_SPEED              │ DOUBLE      │ YES     │ NULL    │ NULL    │  NULL │
# │ HOURLY_WIND_DIRECTION          │ BIGINT      │ YES     │ NULL    │ NULL    │  NULL │
# │ HOURLY_WIND_GUST               │ DOUBLE      │ YES     │ NULL    │ NULL    │  NULL │
# │ HOURLY_FINE_FUEL_MOISTURE_CODE │ DOUBLE      │ YES     │ NULL    │ NULL    │  NULL │
# │          ·                     │   ·         │  ·      │  ·      │  ·      │    ·  │
# │          ·                     │   ·         │  ·      │  ·      │  ·      │    ·  │
# │          ·                     │   ·         │  ·      │  ·      │  ·      │    ·  │
# │ PRECIP_PLUVIO1_TOTAL           │ DOUBLE      │ YES     │ NULL    │ NULL    │  NULL │
# │ RN_1_PLUVIO2                   │ BIGINT      │ YES     │ NULL    │ NULL    │  NULL │
# │ PRECIP_PLUVIO2_STATUS          │ BIGINT      │ YES     │ NULL    │ NULL    │  NULL │
# │ PRECIP_PLUVIO2_TOTAL           │ DOUBLE      │ YES     │ NULL    │ NULL    │  NULL │
# │ RN_1_RIT                       │ VARCHAR     │ YES     │ NULL    │ NULL    │  NULL │
# │ PRECIP_RIT_STATUS              │ BIGINT      │ YES     │ NULL    │ NULL    │  NULL │
# │ PRECIP_RIT_TOTAL               │ DOUBLE      │ YES     │ NULL    │ NULL    │  NULL │
# │ PRECIP_RGT                     │ DOUBLE      │ YES     │ NULL    │ NULL    │  NULL │
# │ SOLAR_RADIATION_LICOR          │ BIGINT      │ YES     │ NULL    │ NULL    │  NULL │
# │ SOLAR_RADIATION_CM3            │ VARCHAR     │ YES     │ NULL    │ NULL    │  NULL │
# ├────────────────────────────────┴─────────────┴─────────┴─────────┴─────────┴───────┤
# │ 34 rows (20 shown)                                                       6 columns │
# └────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## Top 3 precipitation events
# looks like some wet days at station 956

# %%
conn.sql("SELECT STATION_CODE,DATE_TIME,PRECIPITATION FROM weather \
ORDER BY PRECIPITATION DESC LIMIT 3")
# Out:
# ┌──────────────┬────────────┬───────────────┐
# │ STATION_CODE │ DATE_TIME  │ PRECIPITATION │
# │    int64     │   int64    │    double     │
# ├──────────────┼────────────┼───────────────┤
# │          956 │ 2023111112 │         174.0 │
# │          956 │ 2023110412 │         157.2 │
# │         1398 │ 2023110412 │         156.2 │
# └──────────────┴────────────┴───────────────┘

# %% [markdown]
# ## Where to next, Pandas dataframe?

# %%
df = conn.sql("SELECT * FROM weather").to_df()
df
# Out:
#         STATION_CODE STATION_NAME   DATE_TIME  HOURLY_PRECIPITATION  \
# 0                 11       SUMMIT  2023110100                   0.0
# 1                 11       SUMMIT  2023110101                   0.0
# 2                 11       SUMMIT  2023110102                   0.0
# 3                 11       SUMMIT  2023110103                   0.0
# 4                 11       SUMMIT  2023110104                   0.0
# ...              ...          ...         ...                   ...
# 170881          3191     GOATLICK  2023112805                   0.0
# 170882          3191     GOATLICK  2023112806                   0.0
# 170883          3191     GOATLICK  2023112807                   0.0
# 170884          3191     GOATLICK  2023112808                   0.0
# 170885          3191     GOATLICK  2023112809                   0.0
#
#         HOURLY_TEMPERATURE  HOURLY_RELATIVE_HUMIDITY  HOURLY_WIND_SPEED  \
# 0                      6.4                      58.0                0.0
# 1                      6.4                      50.0                0.0
# 2                      7.5                      46.0                0.0
# 3                      6.7                      55.0                0.0
# 4                      6.8                      58.0                0.0
# ...                    ...                       ...                ...
# 170881                -3.2                      69.0                9.8
# 170882                -3.3                      69.0                9.0
# 170883                -3.5                      69.0               12.0
# 170884                -3.6                      70.0                9.3
# 170885                -3.6                      70.0               12.1
#
#         HOURLY_WIND_DIRECTION  HOURLY_WIND_GUST  \
# 0                       129.0               0.0
# 1                        63.0               0.0
# 2                       352.0               0.0
# 3                       131.0               0.0
# 4                       125.0               0.0
# ...                       ...               ...
# 170881                  141.0              28.5
# 170882                  144.0              26.4
# 170883                  147.0              28.2
# 170884                  145.0              27.1
# 170885                  151.0              25.6
#
#         HOURLY_FINE_FUEL_MOISTURE_CODE  ...  PRECIP_PLUVIO1_TOTAL  \
# 0                               88.927  ...                   0.0
# 1                               88.864  ...                   0.0
# 2                               88.848  ...                   0.0
# 3                               88.738  ...                   0.0
# 4                               88.600  ...                   0.0
# ...                                ...  ...                   ...
# 170881                             NaN  ...                   NaN
# 170882                             NaN  ...                   NaN
# 170883                             NaN  ...                   NaN
# 170884                             NaN  ...                   NaN
# 170885                             NaN  ...                   NaN
#
#         RN_1_PLUVIO2  PRECIP_PLUVIO2_STATUS  PRECIP_PLUVIO2_TOTAL  RN_1_RIT  \
# 0                0.0                    0.0                   0.0      None
# 1                0.0                    0.0                   0.0      None
# 2                0.0                    0.0                   0.0      None
# 3                0.0                    0.0                   0.0      None
# 4                0.0                    0.0                   0.0      None
# ...              ...                    ...                   ...       ...
# 170881           NaN                    NaN                   NaN      None
# 170882           NaN                    NaN                   NaN      None
# 170883           NaN                    NaN                   NaN      None
# 170884           NaN                    NaN                   NaN      None
# 170885           NaN                    NaN                   NaN      None
#
#         PRECIP_RIT_STATUS  PRECIP_RIT_TOTAL  PRECIP_RGT  \
# 0                     0.0               0.0         NaN
# 1                     0.0               0.0         NaN
# 2                     0.0               0.0         NaN
# 3                     0.0               0.0         NaN
# 4                     0.0               0.0         NaN
# ...                   ...               ...         ...
# 170881                NaN               NaN       224.4
# 170882                NaN               NaN       224.4
# 170883                NaN               NaN       224.4
# 170884                NaN               NaN       224.4
# 170885                NaN               NaN       224.4
#
#         SOLAR_RADIATION_LICOR  SOLAR_RADIATION_CM3
# 0                         0.0                 None
# 1                         0.0                 None
# 2                         0.0                 None
# 3                         0.0                 None
# 4                         0.0                 None
# ...                       ...                  ...
# 170881                    NaN                 None
# 170882                    NaN                 None
# 170883                    NaN                 None
# 170884                    NaN                 None
# 170885                    NaN                 None
#
# [170886 rows x 34 columns]
